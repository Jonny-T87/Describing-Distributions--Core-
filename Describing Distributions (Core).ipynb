# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
df = pd.read_csv('Data/data (1).csv')
df.head()
# Out:
#   State       Lat       Lng      Area  Children  Age    Income   Marital  \
# 0    AL  34.34960 -86.72508  Suburban       1.0   53  86575.93  Divorced
# 1    FL  30.84513 -85.22907     Urban       3.0   51  46805.99   Married
# 2    SD  43.54321 -96.63772  Suburban       3.0   53  14370.14   Widowed
# 3    MN  43.89744 -93.51479  Suburban       0.0   78  39741.49   Married
# 4    VA  37.59894 -76.88958     Rural       1.0   22   1209.56   Widowed
#
#    Gender  ReAdmis  ...  Hyperlipidemia  BackPain  Anxiety  Allergic_rhinitis  \
# 0    Male        0  ...             0.0       1.0      1.0                1.0
# 1  Female        0  ...             0.0       0.0      0.0                0.0
# 2  Female        0  ...             0.0       0.0      0.0                0.0
# 3    Male        0  ...             0.0       0.0      0.0                0.0
# 4  Female        0  ...             1.0       0.0      0.0                1.0
#
# ...

# %%
features = df[['Doc_visits', 'VitD_levels', 'TotalCharge']]
features.head()
# Out:
#    Doc_visits  VitD_levels  TotalCharge
# 0           6    19.141466  3726.702860
# 1           4    18.940352  4193.190458
# 2           4    18.057507  2434.234222
# 3           4    16.576858  2127.830423
# 4           5    17.439069  2113.073274

# %% [markdown]
# - Doc_visits histogram

# %%
##making mean and median and std for doc visits with hisplot
col = 'Doc_visits'
fea = df[col]
doc_mean = fea.mean()
doc_median = fea.median()
doc_std = fea.std()
plus_one_std = doc_mean + doc_std
minus_one_std = doc_mean - doc_std

fig,ax = plt.subplots(figsize=(10,6))
ax = sns.histplot(data=features, x=fea, stat='probability', kde=True)
ax.axvline(doc_mean, color='red', label=f'Mean = {doc_mean:,.2f}')
ax.axvline(doc_median, ls='--', color='green', label=f'Median = {doc_median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# 1. Is it Discrete or Continuous?
#    - Based on the plot this is discrete and also because the distributions can only take on certain values. Not between any value.
#
# 2. Does it have a skew? If so, which direction (+/-)
#     - The data is not skewed because the mean and median are basically the same.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
#   - This displays a Leptokurtic because values cluster in the peak of the distribution.

# %% [markdown]
# - VitD_levels histogram

# %%
##making mean and median and std for doc visits with hisplot for VitD_levels
col = 'VitD_levels'
fea = df[col]
doc_mean = fea.mean()
doc_median = fea.median()
doc_std = fea.std()
plus_one_std = doc_mean + doc_std
minus_one_std = doc_mean - doc_std

fig,ax = plt.subplots(figsize=(10,6))
ax = sns.histplot(data=features, x=fea, stat='probability', kde=True)
ax.axvline(doc_mean, color='red', label=f'Mean = {doc_mean:,.2f}')
ax.axvline(doc_median, ls='--', color='green', label=f'Median = {doc_median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# 1. Is it Discrete or Continuous?
#    - Based on the plot this is continuous because the distributions can  take on a nearly infinite number of values.
#
# 2. Does it have a skew? If so, which direction (+/-)
#     - The data is not skewed because the mean and median are basically the same also.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
#   - This displays a Leptokurtic because values cluster in the peak of the distribution.

# %% [markdown]
# - TotalCharge histogram

# %%
##making mean and median and std for doc visits with hisplot for TotalCharge
col = 'TotalCharge'
fea = df[col]
doc_mean = fea.mean()
doc_median = fea.median()
doc_std = fea.std()
plus_one_std = doc_mean + doc_std
minus_one_std = doc_mean - doc_std

fig,ax = plt.subplots(figsize=(10,6))
ax = sns.histplot(data=features, x=fea, stat='probability', kde=True)
ax.axvline(doc_mean, color='red', label=f'Mean = {doc_mean:,.2f}')
ax.axvline(doc_median, ls='--', color='green', label=f'Median = {doc_median:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color='yellow', zorder=0)
ax.set_title(f'{col}')
ax.legend();

# %% [markdown]
# 1. Is it Discrete or Continuous?
#    - Based on the plot this is continuous because the distributions can  take on a nearly infinite number of values also.
#
# 2. Does it have a skew? If so, which direction (+/-)
#     - The data is skewed positive because the median is smaller than the mean and the right tail is very long.
#
# 3. What type of kurtosis does it display? (Mesokurtic, Leptokurtic, Platykurtic)
#
#   - This displays a Mesokurtic because values cluster in the middle of the distribution.
